# %% [markdown]
# # IMPORTS

# %%
import sys
import tensorflow as tf
from models import resnet#, uv_rois
import numpy as np
import argparse
import os
from utils.metrics import simple_accuracy
from datetime import datetime
tf.debugging.set_log_device_placement(True)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt


if __name__ == '__main__' :

    '''
    a = tf.zeros([10,120,120,128])
    b = tf.zeros([30,30,3])
    b = tf.expand_dims(b,axis=3)
    a_b = tf.nn.conv2d(a,b,padding='VALID', strides=[1,1,1,1])
    
    print(a_b.shape)
    '''

# %% [markdown]
# # Obtener imagenes y sus anotaciones

# %%
from utils.COCO_Utils.COCO_like_dataset import CocoLikeDataset

# %%
train_images = CocoLikeDataset()
train_images.load_data('/home/jeancherubini/Documents/data/coco_flickrlogos_47/annotations/instances_train.json', '/home/jeancherubini/Documents/data/coco_flickrlogos_47/images/train')
train_images.prepare()

# %%
train_images.image_info[713]
# Out:
# {'id': 713,
#  'source': 'coco_like',
#  'path': '/home/jeancherubini/Documents/data/coco_flickrlogos_47/images/train/000000438.png',
#  'width': 1024,
#  'height': 683,
#  'annotations': [{'id': 1663,
#    'category_id': 8,
#    'iscrowd': 1,
#    'segmentation': {'size': [1024, 683],
#     'counts': [453120,
#      4,
#      454140,
#      12,
#      455160,
#      21,
#      456180,
#      29,
#      457202,
#      32,
#      458225,
#      35,
#      459247,
#      38,
#      460269,
#      41,
#      461292,
#      42,
#      462315,
#      46,
#      463338,
#      48,
#      464362,
#      50,
#      465385,
#      52,
#      466409,
#      53,
#      467432,
#      55,
#      468456,
#      57,
#      469480,
#      58,
#      470503,
#      59,
#      471527,
#      60,
#      472551,
#      61,
#      473575,
#      62,
#      474598,
#      64,
#      475622,
#      65,
#      476646,
#      65,
#      477670,
#      66,
#      478693,
#      67,
#      479714,
#      71,
# ...

# %%
train_images.load_annotations(713)
# Out:
# {'id': 1663, 'category_id': 8, 'iscrowd': 1, 'segmentation': {'size': [1024, 683], 'counts': [453120, 4, 454140, 12, 455160, 21, 456180, 29, 457202, 32, 458225, 35, 459247, 38, 460269, 41, 461292, 42, 462315, 46, 463338, 48, 464362, 50, 465385, 52, 466409, 53, 467432, 55, 468456, 57, 469480, 58, 470503, 59, 471527, 60, 472551, 61, 473575, 62, 474598, 64, 475622, 65, 476646, 65, 477670, 66, 478693, 67, 479714, 71, 480736, 73, 481759, 74, 482782, 75, 483806, 75, 484829, 76, 485852, 77, 486875, 78, 487897, 80, 488919, 82, 489942, 83, 490965, 84, 491989, 84, 493012, 84, 494036, 84, 495059, 85, 496083, 84, 497107, 84, 498131, 84, 499154, 86, 500179, 85, 501203, 85, 502227, 85, 503251, 85, 504275, 85, 505300, 84, 506325, 83, 507349, 83, 508374, 81, 509400, 78, 510432, 70, 511457, 67, 512483, 65, 513511, 61, 514536, 60, 515561, 59, 516585, 59, 517610, 58, 518635, 56, 519659, 55, 520684, 54, 521708, 54, 522732, 54, 523757, 53, 524781, 53, 525806, 51, 526830, 51, 527855, 49, 528879, 48, 52990
# ...

# %%
images = train_images.load_image_batch(range(100))
images.shape
train_images.class_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bbf01da027d0> in <module>
# ----> 1 images = train_images.load_image_batch(range(100))
#       2 images.shape
#       3 train_images.class_info
#
# NameError: name 'train_images' is not defined

# %%
annotations = train_images.load_annotations_batch(range(100))
annotations.shape
# Out:
# (100, 14, 5)

# %%
datagen = ImageDataGenerator(rescale=1./255)
train_flow = datagen.flow(images, annotations, batch_size=10)

# %% [markdown]
# # Obtener Query

# %% [markdown]
# queries_datagenerator = ImageDataGenerator(rescale=1./255)
# queries_flow = queries_datagenerator.flow_from_directory('/home/jeancherubini/Documents/data/coco_flickrlogos_47/images/queries_train', batch_size=1, shuffle=False, class_mode='binary')

# %%
resnet = tf.keras.applications.ResNet50(
    include_top=False, weights='imagenet', input_tensor=None, input_shape=None,
    pooling=None, classes=1000
)
# Out:
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Add in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op LogicalNot in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Assert in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# ...

# %%
for image_data, annots in train_flow:
    print(image_data.shape)
    features = resnet(image_data, training=False)
    plt.figure()
    plt.imshow(image_data[0])
    plt.show()
    plt.figure()
    print(features.shape)
    break
# Out:
# (10, 1024, 1024, 3)
# (10, 32, 32, 2048)

# %%
resnet.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, None, None, 6 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           conv1_bn[0][0]
# ...

# %%
def get_layer_model(model,layer_name):
    #Resnet interesting layers
    #conv1_relu
    #conv2_block3_out
    #conv3_block4_out
    #conv4_block6_out
    #conv5_block3_out
    return tf.keras.Model(model.inputs, model.get_layer(layer_name).output)
        

early_block_model = get_layer_model(resnet, 'conv3_block4_out')
early_block_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, None, None, 6 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           conv1_bn[0][0]
# ...

# %%
features_2 = early_block_model(image_data, training=False)
features_2.shape
# Out:
# TensorShape([10, 128, 128, 512])
